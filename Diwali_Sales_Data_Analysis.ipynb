# %%
# import python libraries

import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt 
# visualizing data
# %matplotlib inline
import seaborn as sns

# %%
# import csv file
df = pd.read_csv('Diwali Sales Data.csv', encoding= 'unicode_escape')

# %%
# Total number of rows & columns
df.shape
# Out:
# (11251, 15)

# %%
# Show First 5 Data
df.head()
# Out:
#    User_ID  Cust_name Product_ID Gender Age Group  Age  Marital_Status  \
# 0  1002903  Sanskriti  P00125942      F     26-35   28               0
# 1  1000732     Kartik  P00110942      F     26-35   35               1
# 2  1001990      Bindu  P00118542      F     26-35   35               1
# 3  1001425     Sudevi  P00237842      M      0-17   16               0
# 4  1000588       Joni  P00057942      M     26-35   28               1
#
#             State      Zone       Occupation Product_Category  Orders  \
# 0     Maharashtra   Western       Healthcare             Auto       1
# 1  Andhra Pradesh  Southern             Govt             Auto       3
# 2   Uttar Pradesh   Central       Automobile             Auto       3
# 3       Karnataka  Southern     Construction             Auto       2
# 4         Gujarat   Western  Food Processing             Auto       2
#
#     Amount  Status  unnamed1
# 0  23952.0     NaN       NaN
# 1  23934.0     NaN       NaN
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11251 entries, 0 to 11250
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   User_ID           11251 non-null  int64
#  1   Cust_name         11251 non-null  object
#  2   Product_ID        11251 non-null  object
#  3   Gender            11251 non-null  object
#  4   Age Group         11251 non-null  object
#  5   Age               11251 non-null  int64
#  6   Marital_Status    11251 non-null  int64
#  7   State             11251 non-null  object
#  8   Zone              11251 non-null  object
#  9   Occupation        11251 non-null  object
#  10  Product_Category  11251 non-null  object
#  11  Orders            11251 non-null  int64
#  12  Amount            11239 non-null  float64
#  13  Status            0 non-null      float64
#  14  unnamed1          0 non-null      float64
# dtypes: float64(3), int64(4), object(8)
# memory usage: 1.3+ MB

# %%
#drop blank columns
df.drop(['Status', 'unnamed1'], axis=1, inplace=True)

# %%
#check for null values
pd.isnull(df).sum()
# Out:
# User_ID              0
# Cust_name            0
# Product_ID           0
# Gender               0
# Age Group            0
# Age                  0
# Marital_Status       0
# State                0
# Zone                 0
# Occupation           0
# Product_Category     0
# Orders               0
# Amount              12
# dtype: int64

# %%
# drop null values
df.dropna(inplace=True)

# %%
# change data type
df['Amount'] = df['Amount'].astype('int')

# %%
# Check datatype
df['Amount'].dtypes
# Out:
# dtype('int32')

# %%
# Show columns
df.columns
# Out:
# Index(['User_ID', 'Cust_name', 'Product_ID', 'Gender', 'Age Group', 'Age',
#        'Marital_Status', 'State', 'Zone', 'Occupation', 'Product_Category',
#        'Orders', 'Amount'],
#       dtype='object')

# %%
# Rename column
df.rename(columns= {"User_ID":"Cust_ID"})
# Out:
#        Cust_ID    Cust_name Product_ID Gender Age Group  Age  Marital_Status  \
# 0      1002903    Sanskriti  P00125942      F     26-35   28               0
# 1      1000732       Kartik  P00110942      F     26-35   35               1
# 2      1001990        Bindu  P00118542      F     26-35   35               1
# 3      1001425       Sudevi  P00237842      M      0-17   16               0
# 4      1000588         Joni  P00057942      M     26-35   28               1
# ...        ...          ...        ...    ...       ...  ...             ...
# 11246  1000695      Manning  P00296942      M     18-25   19               1
# 11247  1004089  Reichenbach  P00171342      M     26-35   33               0
# 11248  1001209        Oshin  P00201342      F     36-45   40               0
# 11249  1004023       Noonan  P00059442      M     36-45   37               0
# 11250  1002744      Brumley  P00281742      F     18-25   19               0
#
# ...

# %%
# describe data in the DataFrame (i.e. count, mean, std, etc)
df.describe()
# Out:
#             User_ID           Age  Marital_Status        Orders        Amount
# count  1.123900e+04  11239.000000    11239.000000  11239.000000  11239.000000
# mean   1.003004e+06     35.410357        0.420055      2.489634   9453.610553
# std    1.716039e+03     12.753866        0.493589      1.114967   5222.355168
# min    1.000001e+06     12.000000        0.000000      1.000000    188.000000
# 25%    1.001492e+06     27.000000        0.000000      2.000000   5443.000000
# 50%    1.003064e+06     33.000000        0.000000      2.000000   8109.000000
# 75%    1.004426e+06     43.000000        1.000000      3.000000  12675.000000
# max    1.006040e+06     92.000000        1.000000      4.000000  23952.000000

# %%
# Use describe() for specific columns
df[['Age', 'Orders', 'Amount']].describe()
# Out:
#                 Age        Orders        Amount
# count  11239.000000  11239.000000  11239.000000
# mean      35.410357      2.489634   9453.610553
# std       12.753866      1.114967   5222.355168
# min       12.000000      1.000000    188.000000
# 25%       27.000000      2.000000   5443.000000
# 50%       33.000000      2.000000   8109.000000
# 75%       43.000000      3.000000  12675.000000
# max       92.000000      4.000000  23952.000000

# %%
# Count Male & Female
df['Gender'].value_counts()
# Out:
# Gender
# F    7832
# M    3407
# Name: count, dtype: int64

# %%
# Use describe() for zones
df['Zone'].describe()
# Out:
# count       11239
# unique          5
# top       Central
# freq         4289
# Name: Zone, dtype: object

# %%
# Different Occupation counts
df['Occupation'].value_counts()
# Out:
# Occupation
# IT Sector          1583
# Healthcare         1408
# Aviation           1310
# Banking            1137
# Govt                854
# Hospitality         703
# Media               637
# Automobile          565
# Chemical            541
# Lawyer              531
# Retail              501
# Food Processing     423
# Construction        414
# Textile             349
# Agriculture         283
# Name: count, dtype: int64

# %%
# Use describe() for Product_ID
df['Product_ID'].describe()
# Out:
# count         11239
# unique         2350
# top       P00265242
# freq             53
# Name: Product_ID, dtype: object

# %%
# Pivot table to show total category wise amount spent by male and female
pd.pivot_table(df, values=['Amount'], index=['Product_Category'], columns=['Gender'])
# Out:
#                              Amount
# Gender                            F             M
# Product_Category
# Auto                   20090.484375  20388.424242
# Beauty                  4690.021538   4486.876289
# Books                  10364.487179  10269.734375
# Clothing & Apparel      6191.533441   6262.067416
# Decor                   7556.886076   7845.058824
# Electronics & Gadgets   7474.997967   7546.234043
# Food                   13651.102202  13571.322670
# Footwear & Shoes       14750.060102  14587.227437
# Furniture              15500.648402  15379.015038
# Games & Toys           11154.791209  11384.389381
# Hand & Power Tools     14122.222222  16383.411765
# Household items         3026.915493   3007.173729
# Office                   733.106667    709.289474
# Pet Care                2302.145833   2217.176471
# Sports Products        10134.518939  10439.347826
# Stationery             15116.898305  14795.358491
# Tupperware             15980.096154  16233.850000
# ...

# %%
# Create pivot table for item wise unit sold.
pd.pivot_table(df,index=['Product_Category'],values=['Orders'],aggfunc=['sum'])
# Out:
#                          sum
#                       Orders
# Product_Category
# Auto                     239
# Beauty                  1086
# Books                    245
# Clothing & Apparel      6634
# Decor                    235
# Electronics & Gadgets   5226
# Food                    6110
# Footwear & Shoes        2646
# Furniture                889
# Games & Toys             940
# Hand & Power Tools        80
# Household items         1331
# Office                   261
# Pet Care                 536
# Sports Products          870
# Stationery               281
# Tupperware               166
# Veterinary               206

# %% [markdown]
# # Exploratory Data Analysis

# %% [markdown]
# ### Gender

# %%
# plotting a pie chart for Gender and it's count
#df.groupby('Gender').size().plot(kind='pie', autopct='%.2f')

labels = ['Female', 'Male']
count = df['Gender'].value_counts()

# Create a pie chart
plt.pie(count, labels=labels, autopct='%1.1f%%', startangle=90, colors=['blue', 'deeppink'])

# Display the chart
plt.show()

# %%
# plotting a bar chart for gender vs total amount

sales_gen = df.groupby(['Gender'], as_index=False)['Amount'].sum().sort_values(by='Amount', ascending=False)
sns.barplot(x = 'Gender',y= 'Amount' ,data = sales_gen)
# Out:
# <Axes: xlabel='Gender', ylabel='Amount'>

# %% [markdown]
# *From above graphs we can see that most of the buyers are females and even the purchasing power of females are greater than men*

# %% [markdown]
# ### Age

# %%
# Plotting a chart of Male & Female based on their Age group
ax = sns.countplot(data = df, x = 'Age Group', hue = 'Gender',palette="Greens")

for bars in ax.containers:
    ax.bar_label(bars)

# %% [markdown]
# *From above graph we can see that most of the customers are of age group between 26-35 yrs
# and the least of the customers are of age group between 0-17 yrs.*

# %%
# Total Amount vs Age Group
sales_age = df.groupby(['Age Group'], as_index=False)['Amount'].sum().sort_values(by='Amount', ascending=False)

sns.barplot(x = 'Age Group',y= 'Amount' ,data = sales_age)
# Out:
# <Axes: xlabel='Age Group', ylabel='Amount'>

# %% [markdown]
# *From above graphs we can see that most of the buyers are of age group between 26-35 yrs female*

# %% [markdown]
# ### Zone

# %%
# plotting a bar chart for zone and it's count

ax = sns.countplot(x = 'Zone',data = df)

for bars in ax.containers:
    ax.bar_label(bars)

# %% [markdown]
# *From above graph we can see that most of the customers are from central zone and least of the customers are from Eastern zone*

# %% [markdown]
# ### State

# %%
# total number of orders from top 10 states

sales_state = df.groupby(['State'], as_index=False)['Orders'].sum().sort_values(by='Orders', ascending=False).head(10)

sns.set(rc={'figure.figsize':(20,5)})
sns.barplot(data = sales_state, x = 'State',y= 'Orders')
# Out:
# <Axes: xlabel='State', ylabel='Orders'>

# %% [markdown]
# *From above graphs we can see that most of the orders are from Uttar Pradesh, Maharashtra and Karnataka and least of orders are from kerala, Haryana and Gujarat respectively*

# %%
# total amount/sales from top 10 states

sales_state = df.groupby(['State'], as_index=False)['Amount'].sum().sort_values(by='Amount', ascending=False).head(10)

sns.set(rc={'figure.figsize':(20,5)})
sns.barplot(data = sales_state, x = 'State',y= 'Amount')
# Out:
# <Axes: xlabel='State', ylabel='Amount'>

# %% [markdown]
# *From above graphs we can see that most of the orders & total sales/amount are from Uttar Pradesh, Maharashtra and Karnataka respectively and the least are from Haryana,Bihar and Gujarat*

# %% [markdown]
# ### Marital Status

# %%
ax = sns.countplot(data = df, x = 'Marital_Status')

sns.set(rc={'figure.figsize':(7,5)})
for bars in ax.containers:
    ax.bar_label(bars)

# %% [markdown]
# *Here 0 means Married and 1 means Unmarried*

# %%
sales_state = df.groupby(['Marital_Status', 'Gender'], as_index=False)['Amount'].sum().sort_values(by='Amount', ascending=False)

sns.set(rc={'figure.figsize':(6,5)})
sns.barplot(data = sales_state, x = 'Marital_Status',y= 'Amount', hue='Gender')
# Out:
# <Axes: xlabel='Marital_Status', ylabel='Amount'>

# %% [markdown]
# *From above graphs we can see that most of the buyers are married (women) and they have high purchasing power*

# %% [markdown]
# ### Occupation

# %%
sns.set(rc={'figure.figsize':(20,5)})
ax = sns.countplot(data = df, x = 'Occupation')

for bars in ax.containers:
    ax.bar_label(bars)

# %%
sales_state = df.groupby(['Occupation'], as_index=False)['Amount'].sum().sort_values(by='Amount', ascending=False)

sns.set(rc={'figure.figsize':(20,5)})
sns.barplot(data = sales_state, x = 'Occupation',y= 'Amount')
# Out:
# <Axes: xlabel='Occupation', ylabel='Amount'>

# %% [markdown]
# *From above graphs we can see that most of the buyers are working in IT, Healthcare and Aviation sector*
# *and the least of the buyers are in Textile and Agriculture.*

# %% [markdown]
# ### Product Category

# %%
sns.set(rc={'figure.figsize':(25,8)})
ax = sns.countplot(data = df, x = 'Product_Category')

for bars in ax.containers:
    ax.bar_label(bars)

# %%
sales_state = df.groupby(['Product_Category'], as_index=False)['Amount'].sum().sort_values(by='Amount', ascending=False).head(10)

sns.set(rc={'figure.figsize':(20,5)})
sns.barplot(data = sales_state, x = 'Product_Category',y= 'Amount')
# Out:
# <Axes: xlabel='Product_Category', ylabel='Amount'>

# %% [markdown]
# *From above graphs we can see that most of the sold products are from Food, Clothing and Electronics category and least of the sold products are from beauty,Auto and Stationery*

# %%
# Show top 10 sold product ID
sales_state = df.groupby(['Product_ID'], as_index=False)['Orders'].sum().sort_values(by='Orders', ascending=False).head(10)

sns.set(rc={'figure.figsize':(20,5)})
sns.barplot(data = sales_state, x = 'Product_ID',y= 'Orders')
# Out:
# <Axes: xlabel='Product_ID', ylabel='Orders'>

# %% [markdown]
# *From above graph we can see the most sold Product_ID is P00265242*

# %% [markdown]
# ## Conclusion:
#
# ###

# %% [markdown]
# *In conclusion, our Diwali sales data analysis has unearthed several crucial insights that shed light on the performance of our business during this festive period.*
#
# *Married women age group 26-35 yrs from UP, Maharastra and Karnataka working in IT, Healthcare and Aviation are more likely to buy products from Food, Clothing and Electronics category and Zone wise sales patterns exhibited distinct variations.*

# %% [markdown]
# ## Expressing Gratitude:

# %% [markdown]
# *As we draw the curtains on our Diwali sales data analysis presentation, we want to express our heartfelt gratitude for the opportunity to share our findings with you today. This project wouldn't have been possible without the collaborative efforts of our dedicated team members, each contributing their unique skills and perspectives.*

# %% [markdown]
# Now We welcome any questions or feedback from the audience. Thank You.

# %% [markdown]
# ***Presented By- Aditi Panja, Aparna Kumar, Anindita Chatterjee, Dipti Karmakar***
